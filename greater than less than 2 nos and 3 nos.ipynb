# %%
a = int(input("enter the value of 1st number"))
b = int(input("enter the value of 2nd number"))
if a>b:
    print("1st number is greater than the 2nd number")
if b>a:
    print("2nd number is greater than the 1st number")
if a==b:
    print("both the numbers are equal")
# Out:
# enter the value of 1st number3
# enter the value of 2nd number1
# 1st number is greater than the 2nd number

# %%
a = int(input("enter the value of 1st number"))
b = int(input("enter the value of 2nd number"))
c = int(input("enter the value of 3rd number"))
if a>b and b>c:
    print("first number is greater")
if b>a and b>c:
    print("2nd number is greater")
if c>a and c>b:
    print("3rd number is greater")
if a==b==c:
    print("all 3 are equal")
# Out:
# enter the value of 1st number1
# enter the value of 2nd number1
# enter the value of 3rd number1
# all 3 are equal
